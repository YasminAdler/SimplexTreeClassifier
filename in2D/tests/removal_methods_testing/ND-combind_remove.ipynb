# %% [markdown]
# # N-Dimensional Simplex Tree Testing
#
# This notebook tests the SimplexTreeClassifier with data of various dimensions (3D, 4D, 5D, etc.).

# %%
import numpy as np
import sys
import os

current_dir = os.getcwd()
parent_dir = os.path.join(current_dir, '..', '..')
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC
from in2D.classifying.classes.simplex_tree_classifier import SimplexTreeClassifier
from in2D.classifying.classes.utilss.convexity_check import check_convexity, get_shared_vertices
from data_generators.generate_data_nd import create_simplex_vertices

# %% [markdown]
# ## Helper function for testing any dimension

# %%
def test_nd_simplex_tree(dimensions, subdivision_levels=3, C=10000, EPSILON=0.30):
    print(f"\n{'='*60}")
    print(f"Testing {dimensions}D Simplex Tree")
    print(f"{'='*60}")
    
    data = np.load(f'datasets/dataset_{dimensions}d.npz')
    X, y = data['X'], data['y']
    print(f"Dataset: {X.shape[0]} points, Dimensions: {X.shape[1]}, Classes: {np.unique(y)}")
    
    root_vertices = create_simplex_vertices(dimensions)
    print(f"Root simplex has {len(root_vertices)} vertices")
    
    model = SimplexTreeClassifier(
        vertices=root_vertices,
        classifier=LinearSVC(C=C),
        subdivision_levels=subdivision_levels,
    )
    model.fit(X, y)
    print(f"Model built with {len(model.leaf_simplexes)} leaf simplices")

    weights = model.classifier.coef_[0]
    intercept = model.classifier.intercept_[0]
    min_shared = dimensions  # In ND, adjacent simplices share a (D-1)-face with D vertices
    
    nonconvex_simplex_keys = set()
    crossing_simplices = model.identify_svm_crossing_simplices()
    for i, info1 in enumerate(crossing_simplices):
        simplex1 = info1['simplex']
        for info2 in crossing_simplices[i+1:]:
            simplex2 = info2['simplex']
            shared = get_shared_vertices(simplex1, simplex2)
            if len(shared) >= min_shared:
                is_convex, avg, meeting, pt1, pt2 = check_convexity(
                    simplex1, simplex2, weights, intercept,
                    global_tree=model.tree, epsilon=EPSILON
                )
                if not is_convex:
                    nonconvex_simplex_keys.add(frozenset(simplex1.vertex_indices))
                    nonconvex_simplex_keys.add(frozenset(simplex2.vertex_indices))
    
    same_side_simplex_keys = model.find_same_side_simplices()
    combined_keys = nonconvex_simplex_keys.union(same_side_simplex_keys)
    
    print(f"\nSimplices to remove:")
    print(f"  Non-convex: {len(nonconvex_simplex_keys)}")
    print(f"  Same-side: {len(same_side_simplex_keys)}")
    print(f"  Combined: {len(combined_keys)}")
    print(f"  Leaves before: {len(model.tree.get_leaves())}")
    
    removed_count = 0
    for simplex_key in combined_keys:
        if model.tree.remove_by_leaf_key(simplex_key):
            removed_count += 1
    
    if removed_count > 0:
        model._build_node_lookup()
        model.fit(X, y)
    
    print(f"\nAfter removal:")
    print(f"  Removed: {removed_count}")
    print(f"  Leaves remaining: {len(model.tree.get_leaves())}")
    
    model.tree.print_tree(show_only_splitting_points=False)
    
    return model

# %%
def compute_accuracy(model, dimensions):
    data = np.load(f'datasets/dataset_{dimensions}d.npz')
    X, y = data['X'], data['y']
    y_pred = model.predict(X)
    acc = accuracy_score(y, y_pred) * 100
    print(f"{dimensions}D Model Accuracy: {acc:.2f}%")
    return acc

# %% [markdown]
# ## Test 2D

# %%
model_2d = test_nd_simplex_tree(dimensions=2, subdivision_levels=4)
# Out:
# ============================================================
# Testing 2D Simplex Tree
# ============================================================
# Dataset: 790 points, Dimensions: 2, Classes: [-1.  1.]
# Root simplex has 3 vertices
# (790, 43)
# Model built with 81 leaf simplices
#
# Simplices to remove:
#   Non-convex: 24
#   Same-side: 39
#   Combined: 63
#   Leaves before: 81
# (790, 43)
#
# After removal:
#   Removed: 26
#   Leaves remaining: 29
# └── [0] vertices: [0, 1, 2]
#     ├── [1] vertices: [1, 2, 3]
#     │   ├── [2] vertices: [2, 3, 4]
#     │   │   ├── vertices: [3, 4, 5]
#     │   │   ├── vertices: [2, 4, 5]
#     │   │   └── vertices: [2, 3, 5]
#     │   ├── [6] vertices: [1, 3, 4]
#     │   │   ├── vertices: [3, 4, 9]
#     │   │   ├── vertices: [1, 4, 9]
#     │   │   └── vertices: [1, 3, 9]
#     │   └── [10] vertices: [1, 2, 4]
#     │       ├── vertices: [2, 4, 13]
#     │       ├── vertices: [1, 4, 13]
#     │       └── vertices: [1, 2, 13]
#     ├── [14] vertices: [0, 2, 3]
#     │   ├── [15] vertices: [2, 3, 17]
#     │   │   ├── vertices: [3, 17, 18]
#     │   │   ├── vertices: [2, 17, 18]
#     │   │   └── vertices: [2, 3, 18]
#     │   ├── [19] vertices: [0, 3, 17]
#     │   │   ├── vertices: [3, 17, 22]
#     │   │   ├── vertices: [0, 17, 22]
#     │   │   └── vertices: [0, 3, 22]
#     │   └── [23] vertices: [0, 2, 17]
#     │       ├── vertices: [2, 17, 26]
#     │       ├── vertices: [0, 17, 26]
#     │       └── vertices: [0, 2, 26]
#     └── [27] vertices: [0, 1, 3]
#         ├── [28] vertices: [1, 3, 30]
#         │   ├── vertices: [3, 30, 31]
#         │   ├── vertices: [1, 30, 31]
#         │   └── vertices: [1, 3, 31]
#         ├── [32] vertices: [0, 3, 30]
#         │   ├── [33] vertices: [3, 30, 35]
#         │   │   ├── vertices: [30, 35, 36]
#         │   │   ├── vertices: [3, 35, 36]
#         │   │   └── vertices: [3, 30, 36]
#         │   ├── vertices: [0, 30, 35]
#         │   └── vertices: [0, 3, 35]
#         └── [36] vertices: [0, 1, 30]
#             ├── vertices: [1, 30, 39]
#             ├── vertices: [0, 30, 39]
#             └── vertices: [0, 1, 39]

# %%
compute_accuracy(model_2d, 2)
# Out:
# 2D Model Accuracy: 99.49%
# 99.49367088607595

# %% [markdown]
# ## Test 3D

# %%
model_3d = test_nd_simplex_tree(dimensions=3, subdivision_levels=4)
# Out:
# ============================================================
# Testing 3D Simplex Tree
# ============================================================
# Dataset: 759 points, Dimensions: 3, Classes: [-1.  1.]
# Root simplex has 4 vertices
# (759, 89)
# Model built with 256 leaf simplices
#
# Simplices to remove:
#   Non-convex: 131
#   Same-side: 80
#   Combined: 211
#   Leaves before: 256
# (759, 89)
#
# After removal:
#   Removed: 63
#   Leaves remaining: 67
# └── [0] vertices: [0, 1, 2, 3]
#     ├── [1] vertices: [1, 2, 3, 4]
#     │   ├── [2] vertices: [2, 3, 4, 5]
#     │   │   ├── vertices: [3, 4, 5, 6]
#     │   │   ├── vertices: [2, 4, 5, 6]
#     │   │   ├── vertices: [2, 3, 5, 6]
#     │   │   └── vertices: [2, 3, 4, 6]
#     │   ├── [7] vertices: [1, 3, 4, 5]
#     │   │   ├── vertices: [3, 4, 5, 11]
#     │   │   ├── vertices: [1, 4, 5, 11]
#     │   │   ├── vertices: [1, 3, 5, 11]
#     │   │   └── vertices: [1, 3, 4, 11]
#     │   ├── [12] vertices: [1, 2, 4, 5]
#     │   │   ├── vertices: [2, 4, 5, 16]
#     │   │   ├── vertices: [1, 4, 5, 16]
#     │   │   ├── vertices: [1, 2, 5, 16]
#     │   │   └── vertices: [1, 2, 4, 16]
#     │   └── [17] vertices: [1, 2, 3, 5]
#     │       ├── vertices: [2, 3, 5, 21]
#     │       ├── vertices: [1, 3, 5, 21]
#     │       ├── vertices: [1, 2, 5, 21]
#     │       └── vertices: [1, 2, 3, 21]
#     ├── [22] vertices: [0, 2, 3, 4]
#     │   ├── [23] vertices: [2, 3, 4, 26]
#     │   │   ├── vertices: [3, 4, 26, 27]
#     │   │   ├── vertices: [2, 4, 26, 27]
#     │   │   ├── vertices: [2, 3, 26, 27]
#     │   │   └── vertices: [2, 3, 4, 27]
#     │   ├── [28] vertices: [0, 3, 4, 26]
#     │   │   ├── vertices: [3, 4, 26, 32]
#     │   │   ├── vertices: [0, 4, 26, 32]
#     │   │   ├── vertices: [0, 3, 26, 32]
#     │   │   └── vertices: [0, 3, 4, 32]
#     │   ├── [33] vertices: [0, 2, 4, 26]
#     │   │   ├── vertices: [2, 4, 26, 37]
#     │   │   ├── vertices: [0, 4, 26, 37]
#     │   │   ├── vertices: [0, 2, 26, 37]
#     │   │   └── vertices: [0, 2, 4, 37]
#     │   └── [38] vertices: [0, 2, 3, 26]
#     │       ├── vertices: [2, 3, 26, 42]
#     │       ├── vertices: [0, 3, 26, 42]
#     │       ├── vertices: [0, 2, 26, 42]
#     │       └── vertices: [0, 2, 3, 42]
#     ├── [43] vertices: [0, 1, 3, 4]
#     │   ├── [44] vertices: [1, 3, 4, 47]
#     │   │   ├── vertices: [3, 4, 47, 48]
#     │   │   ├── vertices: [1, 4, 47, 48]
#     │   │   ├── vertices: [1, 3, 47, 48]
#     │   │   └── vertices: [1, 3, 4, 48]
#     │   ├── [49] vertices: [0, 3, 4, 47]
#     │   │   ├── vertices: [3, 4, 47, 53]
#     │   │   ├── vertices: [0, 4, 47, 53]
#     │   │   ├── vertices: [0, 3, 47, 53]
#     │   │   └── vertices: [0, 3, 4, 53]
#     │   ├── [54] vertices: [0, 1, 4, 47]
#     │   │   ├── vertices: [1, 4, 47, 58]
#     │   │   ├── [56] vertices: [0, 4, 47, 58]
#     │   │   │   ├── vertices: [4, 47, 58, 60]
#     │   │   │   ├── vertices: [0, 47, 58, 60]
#     │   │   │   ├── vertices: [0, 4, 58, 60]
#     │   │   │   └── vertices: [0, 4, 47, 60]
#     │   │   ├── vertices: [0, 1, 47, 58]
#     │   │   └── vertices: [0, 1, 4, 58]
#     │   └── [59] vertices: [0, 1, 3, 47]
#     │       ├── vertices: [1, 3, 47, 63]
#     │       ├── vertices: [0, 3, 47, 63]
#     │       ├── vertices: [0, 1, 47, 63]
#     │       └── vertices: [0, 1, 3, 63]
#     └── [64] vertices: [0, 1, 2, 4]
#         ├── [65] vertices: [1, 2, 4, 68]
#         │   ├── vertices: [2, 4, 68, 69]
#         │   ├── vertices: [1, 4, 68, 69]
#         │   ├── vertices: [1, 2, 68, 69]
#         │   └── vertices: [1, 2, 4, 69]
#         ├── [70] vertices: [0, 2, 4, 68]
#         │   ├── vertices: [2, 4, 68, 74]
#         │   ├── vertices: [0, 4, 68, 74]
#         │   ├── vertices: [0, 2, 68, 74]
#         │   └── vertices: [0, 2, 4, 74]
#         ├── [75] vertices: [0, 1, 4, 68]
#         │   ├── vertices: [1, 4, 68, 79]
#         │   ├── vertices: [0, 4, 68, 79]
#         │   ├── vertices: [0, 1, 68, 79]
#         │   └── vertices: [0, 1, 4, 79]
#         └── [80] vertices: [0, 1, 2, 68]
#             ├── vertices: [1, 2, 68, 84]
#             ├── vertices: [0, 2, 68, 84]
#             ├── vertices: [0, 1, 68, 84]
#             └── vertices: [0, 1, 2, 84]

# %%
compute_accuracy(model_3d, 3)
# Out:
# 3D Model Accuracy: 94.33%
# 94.33465085638998

# %% [markdown]
# ## Test 4D

# %%
model_4d = test_nd_simplex_tree(dimensions=4, subdivision_levels=4)
# Out:
# ============================================================
# Testing 4D Simplex Tree
# ============================================================
# Dataset: 751 points, Dimensions: 4, Classes: [-1.  1.]
# Root simplex has 5 vertices
# (751, 161)
# Model built with 625 leaf simplices
#
# Simplices to remove:
#   Non-convex: 483
#   Same-side: 60
#   Combined: 543
#   Leaves before: 625
# (751, 161)
#
# After removal:
#   Removed: 125
#   Leaves remaining: 125
# └── [0] vertices: [0, 1, 2, 3, 4]
#     ├── [1] vertices: [1, 2, 3, 4, 5]
#     │   ├── [2] vertices: [2, 3, 4, 5, 6]
#     │   │   ├── vertices: [3, 4, 5, 6, 7]
#     │   │   ├── vertices: [2, 4, 5, 6, 7]
#     │   │   ├── vertices: [2, 3, 5, 6, 7]
#     │   │   ├── vertices: [2, 3, 4, 6, 7]
#     │   │   └── vertices: [2, 3, 4, 5, 7]
#     │   ├── [8] vertices: [1, 3, 4, 5, 6]
#     │   │   ├── vertices: [3, 4, 5, 6, 13]
#     │   │   ├── vertices: [1, 4, 5, 6, 13]
#     │   │   ├── vertices: [1, 3, 5, 6, 13]
#     │   │   ├── vertices: [1, 3, 4, 6, 13]
#     │   │   └── vertices: [1, 3, 4, 5, 13]
#     │   ├── [14] vertices: [1, 2, 4, 5, 6]
#     │   │   ├── vertices: [2, 4, 5, 6, 19]
#     │   │   ├── vertices: [1, 4, 5, 6, 19]
#     │   │   ├── vertices: [1, 2, 5, 6, 19]
#     │   │   ├── vertices: [1, 2, 4, 6, 19]
#     │   │   └── vertices: [1, 2, 4, 5, 19]
#     │   ├── [20] vertices: [1, 2, 3, 5, 6]
#     │   │   ├── vertices: [2, 3, 5, 6, 25]
#     │   │   ├── vertices: [1, 3, 5, 6, 25]
#     │   │   ├── vertices: [1, 2, 5, 6, 25]
#     │   │   ├── vertices: [1, 2, 3, 6, 25]
#     │   │   └── vertices: [1, 2, 3, 5, 25]
#     │   └── [26] vertices: [1, 2, 3, 4, 6]
#     │       ├── vertices: [2, 3, 4, 6, 31]
#     │       ├── vertices: [1, 3, 4, 6, 31]
#     │       ├── vertices: [1, 2, 4, 6, 31]
#     │       ├── vertices: [1, 2, 3, 6, 31]
#     │       └── vertices: [1, 2, 3, 4, 31]
#     ├── [32] vertices: [0, 2, 3, 4, 5]
#     │   ├── [33] vertices: [2, 3, 4, 5, 37]
#     │   │   ├── vertices: [3, 4, 5, 37, 38]
#     │   │   ├── vertices: [2, 4, 5, 37, 38]
#     │   │   ├── vertices: [2, 3, 5, 37, 38]
#     │   │   ├── vertices: [2, 3, 4, 37, 38]
#     │   │   └── vertices: [2, 3, 4, 5, 38]
#     │   ├── [39] vertices: [0, 3, 4, 5, 37]
#     │   │   ├── vertices: [3, 4, 5, 37, 44]
#     │   │   ├── vertices: [0, 4, 5, 37, 44]
#     │   │   ├── vertices: [0, 3, 5, 37, 44]
#     │   │   ├── vertices: [0, 3, 4, 37, 44]
#     │   │   └── vertices: [0, 3, 4, 5, 44]
#     │   ├── [45] vertices: [0, 2, 4, 5, 37]
#     │   │   ├── vertices: [2, 4, 5, 37, 50]
#     │   │   ├── vertices: [0, 4, 5, 37, 50]
#     │   │   ├── vertices: [0, 2, 5, 37, 50]
#     │   │   ├── vertices: [0, 2, 4, 37, 50]
#     │   │   └── vertices: [0, 2, 4, 5, 50]
#     │   ├── [51] vertices: [0, 2, 3, 5, 37]
#     │   │   ├── vertices: [2, 3, 5, 37, 56]
#     │   │   ├── vertices: [0, 3, 5, 37, 56]
#     │   │   ├── vertices: [0, 2, 5, 37, 56]
#     │   │   ├── vertices: [0, 2, 3, 37, 56]
#     │   │   └── vertices: [0, 2, 3, 5, 56]
#     │   └── [57] vertices: [0, 2, 3, 4, 37]
#     │       ├── vertices: [2, 3, 4, 37, 62]
#     │       ├── vertices: [0, 3, 4, 37, 62]
#     │       ├── vertices: [0, 2, 4, 37, 62]
#     │       ├── vertices: [0, 2, 3, 37, 62]
#     │       └── vertices: [0, 2, 3, 4, 62]
#     ├── [63] vertices: [0, 1, 3, 4, 5]
#     │   ├── [64] vertices: [1, 3, 4, 5, 68]
#     │   │   ├── vertices: [3, 4, 5, 68, 69]
#     │   │   ├── vertices: [1, 4, 5, 68, 69]
#     │   │   ├── vertices: [1, 3, 5, 68, 69]
#     │   │   ├── vertices: [1, 3, 4, 68, 69]
#     │   │   └── vertices: [1, 3, 4, 5, 69]
#     │   ├── [70] vertices: [0, 3, 4, 5, 68]
#     │   │   ├── vertices: [3, 4, 5, 68, 75]
#     │   │   ├── vertices: [0, 4, 5, 68, 75]
#     │   │   ├── vertices: [0, 3, 5, 68, 75]
#     │   │   ├── vertices: [0, 3, 4, 68, 75]
#     │   │   └── vertices: [0, 3, 4, 5, 75]
#     │   ├── [76] vertices: [0, 1, 4, 5, 68]
#     │   │   ├── vertices: [1, 4, 5, 68, 81]
#     │   │   ├── vertices: [0, 4, 5, 68, 81]
#     │   │   ├── vertices: [0, 1, 5, 68, 81]
#     │   │   ├── vertices: [0, 1, 4, 68, 81]
#     │   │   └── vertices: [0, 1, 4, 5, 81]
#     │   ├── [82] vertices: [0, 1, 3, 5, 68]
#     │   │   ├── vertices: [1, 3, 5, 68, 87]
#     │   │   ├── vertices: [0, 3, 5, 68, 87]
#     │   │   ├── vertices: [0, 1, 5, 68, 87]
#     │   │   ├── vertices: [0, 1, 3, 68, 87]
#     │   │   └── vertices: [0, 1, 3, 5, 87]
#     │   └── [88] vertices: [0, 1, 3, 4, 68]
#     │       ├── vertices: [1, 3, 4, 68, 93]
#     │       ├── vertices: [0, 3, 4, 68, 93]
#     │       ├── vertices: [0, 1, 4, 68, 93]
#     │       ├── vertices: [0, 1, 3, 68, 93]
#     │       └── vertices: [0, 1, 3, 4, 93]
#     ├── [94] vertices: [0, 1, 2, 4, 5]
#     │   ├── [95] vertices: [1, 2, 4, 5, 99]
#     │   │   ├── vertices: [2, 4, 5, 99, 100]
#     │   │   ├── vertices: [1, 4, 5, 99, 100]
#     │   │   ├── vertices: [1, 2, 5, 99, 100]
#     │   │   ├── vertices: [1, 2, 4, 99, 100]
#     │   │   └── vertices: [1, 2, 4, 5, 100]
#     │   ├── [101] vertices: [0, 2, 4, 5, 99]
#     │   │   ├── vertices: [2, 4, 5, 99, 106]
#     │   │   ├── vertices: [0, 4, 5, 99, 106]
#     │   │   ├── vertices: [0, 2, 5, 99, 106]
#     │   │   ├── vertices: [0, 2, 4, 99, 106]
#     │   │   └── vertices: [0, 2, 4, 5, 106]
#     │   ├── [107] vertices: [0, 1, 4, 5, 99]
#     │   │   ├── vertices: [1, 4, 5, 99, 112]
#     │   │   ├── vertices: [0, 4, 5, 99, 112]
#     │   │   ├── vertices: [0, 1, 5, 99, 112]
#     │   │   ├── vertices: [0, 1, 4, 99, 112]
#     │   │   └── vertices: [0, 1, 4, 5, 112]
#     │   ├── [113] vertices: [0, 1, 2, 5, 99]
#     │   │   ├── vertices: [1, 2, 5, 99, 118]
#     │   │   ├── vertices: [0, 2, 5, 99, 118]
#     │   │   ├── vertices: [0, 1, 5, 99, 118]
#     │   │   ├── vertices: [0, 1, 2, 99, 118]
#     │   │   └── vertices: [0, 1, 2, 5, 118]
#     │   └── [119] vertices: [0, 1, 2, 4, 99]
#     │       ├── vertices: [1, 2, 4, 99, 124]
#     │       ├── vertices: [0, 2, 4, 99, 124]
#     │       ├── vertices: [0, 1, 4, 99, 124]
#     │       ├── vertices: [0, 1, 2, 99, 124]
#     │       └── vertices: [0, 1, 2, 4, 124]
#     └── [125] vertices: [0, 1, 2, 3, 5]
#         ├── [126] vertices: [1, 2, 3, 5, 130]
#         │   ├── vertices: [2, 3, 5, 130, 131]
#         │   ├── vertices: [1, 3, 5, 130, 131]
#         │   ├── vertices: [1, 2, 5, 130, 131]
#         │   ├── vertices: [1, 2, 3, 130, 131]
#         │   └── vertices: [1, 2, 3, 5, 131]
#         ├── [132] vertices: [0, 2, 3, 5, 130]
#         │   ├── vertices: [2, 3, 5, 130, 137]
#         │   ├── vertices: [0, 3, 5, 130, 137]
#         │   ├── vertices: [0, 2, 5, 130, 137]
#         │   ├── vertices: [0, 2, 3, 130, 137]
#         │   └── vertices: [0, 2, 3, 5, 137]
#         ├── [138] vertices: [0, 1, 3, 5, 130]
#         │   ├── vertices: [1, 3, 5, 130, 143]
#         │   ├── vertices: [0, 3, 5, 130, 143]
#         │   ├── vertices: [0, 1, 5, 130, 143]
#         │   ├── vertices: [0, 1, 3, 130, 143]
#         │   └── vertices: [0, 1, 3, 5, 143]
#         ├── [144] vertices: [0, 1, 2, 5, 130]
#         │   ├── vertices: [1, 2, 5, 130, 149]
#         │   ├── vertices: [0, 2, 5, 130, 149]
#         │   ├── vertices: [0, 1, 5, 130, 149]
#         │   ├── vertices: [0, 1, 2, 130, 149]
#         │   └── vertices: [0, 1, 2, 5, 149]
#         └── [150] vertices: [0, 1, 2, 3, 130]
#             ├── vertices: [1, 2, 3, 130, 155]
#             ├── vertices: [0, 2, 3, 130, 155]
#             ├── vertices: [0, 1, 3, 130, 155]
#             ├── vertices: [0, 1, 2, 130, 155]
#             └── vertices: [0, 1, 2, 3, 155]

# %%
compute_accuracy(model_4d, 4)
# Out:
# 4D Model Accuracy: 72.70%
# 72.70306258322236

# %%
model_5d = test_nd_simplex_tree(dimensions=5, subdivision_levels=4)
# Out:
# ============================================================
# Testing 5D Simplex Tree
# ============================================================
# Dataset: 706 points, Dimensions: 5, Classes: [-1.  1.]
# Root simplex has 6 vertices
# (706, 265)
# Model built with 1296 leaf simplices
#
# Simplices to remove:
#   Non-convex: 1250
#   Same-side: 0
#   Combined: 1250
#   Leaves before: 1296
# (706, 265)
#
# After removal:
#   Removed: 216
#   Leaves remaining: 216
# └── [0] vertices: [0, 1, 2, 3, 4, 5]
#     ├── [1] vertices: [1, 2, 3, 4, 5, 6]
#     │   ├── [2] vertices: [2, 3, 4, 5, 6, 7]
#     │   │   ├── vertices: [3, 4, 5, 6, 7, 8]
#     │   │   ├── vertices: [2, 4, 5, 6, 7, 8]
#     │   │   ├── vertices: [2, 3, 5, 6, 7, 8]
#     │   │   ├── vertices: [2, 3, 4, 6, 7, 8]
#     │   │   ├── vertices: [2, 3, 4, 5, 7, 8]
#     │   │   └── vertices: [2, 3, 4, 5, 6, 8]
#     │   ├── [9] vertices: [1, 3, 4, 5, 6, 7]
#     │   │   ├── vertices: [3, 4, 5, 6, 7, 15]
#     │   │   ├── vertices: [1, 4, 5, 6, 7, 15]
#     │   │   ├── vertices: [1, 3, 5, 6, 7, 15]
#     │   │   ├── vertices: [1, 3, 4, 6, 7, 15]
#     │   │   ├── vertices: [1, 3, 4, 5, 7, 15]
#     │   │   └── vertices: [1, 3, 4, 5, 6, 15]
#     │   ├── [16] vertices: [1, 2, 4, 5, 6, 7]
#     │   │   ├── vertices: [2, 4, 5, 6, 7, 22]
#     │   │   ├── vertices: [1, 4, 5, 6, 7, 22]
#     │   │   ├── vertices: [1, 2, 5, 6, 7, 22]
#     │   │   ├── vertices: [1, 2, 4, 6, 7, 22]
#     │   │   ├── vertices: [1, 2, 4, 5, 7, 22]
#     │   │   └── vertices: [1, 2, 4, 5, 6, 22]
#     │   ├── [23] vertices: [1, 2, 3, 5, 6, 7]
#     │   │   ├── vertices: [2, 3, 5, 6, 7, 29]
#     │   │   ├── vertices: [1, 3, 5, 6, 7, 29]
#     │   │   ├── vertices: [1, 2, 5, 6, 7, 29]
#     │   │   ├── vertices: [1, 2, 3, 6, 7, 29]
#     │   │   ├── vertices: [1, 2, 3, 5, 7, 29]
#     │   │   └── vertices: [1, 2, 3, 5, 6, 29]
#     │   ├── [30] vertices: [1, 2, 3, 4, 6, 7]
#     │   │   ├── vertices: [2, 3, 4, 6, 7, 36]
#     │   │   ├── vertices: [1, 3, 4, 6, 7, 36]
#     │   │   ├── vertices: [1, 2, 4, 6, 7, 36]
#     │   │   ├── vertices: [1, 2, 3, 6, 7, 36]
#     │   │   ├── vertices: [1, 2, 3, 4, 7, 36]
#     │   │   └── vertices: [1, 2, 3, 4, 6, 36]
#     │   └── [37] vertices: [1, 2, 3, 4, 5, 7]
#     │       ├── vertices: [2, 3, 4, 5, 7, 43]
#     │       ├── vertices: [1, 3, 4, 5, 7, 43]
#     │       ├── vertices: [1, 2, 4, 5, 7, 43]
#     │       ├── vertices: [1, 2, 3, 5, 7, 43]
#     │       ├── vertices: [1, 2, 3, 4, 7, 43]
#     │       └── vertices: [1, 2, 3, 4, 5, 43]
#     ├── [44] vertices: [0, 2, 3, 4, 5, 6]
#     │   ├── [45] vertices: [2, 3, 4, 5, 6, 50]
#     │   │   ├── vertices: [3, 4, 5, 6, 50, 51]
#     │   │   ├── vertices: [2, 4, 5, 6, 50, 51]
#     │   │   ├── vertices: [2, 3, 5, 6, 50, 51]
#     │   │   ├── vertices: [2, 3, 4, 6, 50, 51]
#     │   │   ├── vertices: [2, 3, 4, 5, 50, 51]
#     │   │   └── vertices: [2, 3, 4, 5, 6, 51]
#     │   ├── [52] vertices: [0, 3, 4, 5, 6, 50]
#     │   │   ├── vertices: [3, 4, 5, 6, 50, 58]
#     │   │   ├── vertices: [0, 4, 5, 6, 50, 58]
#     │   │   ├── vertices: [0, 3, 5, 6, 50, 58]
#     │   │   ├── vertices: [0, 3, 4, 6, 50, 58]
#     │   │   ├── vertices: [0, 3, 4, 5, 50, 58]
#     │   │   └── vertices: [0, 3, 4, 5, 6, 58]
#     │   ├── [59] vertices: [0, 2, 4, 5, 6, 50]
#     │   │   ├── vertices: [2, 4, 5, 6, 50, 65]
#     │   │   ├── vertices: [0, 4, 5, 6, 50, 65]
#     │   │   ├── vertices: [0, 2, 5, 6, 50, 65]
#     │   │   ├── vertices: [0, 2, 4, 6, 50, 65]
#     │   │   ├── vertices: [0, 2, 4, 5, 50, 65]
#     │   │   └── vertices: [0, 2, 4, 5, 6, 65]
#     │   ├── [66] vertices: [0, 2, 3, 5, 6, 50]
#     │   │   ├── vertices: [2, 3, 5, 6, 50, 72]
#     │   │   ├── vertices: [0, 3, 5, 6, 50, 72]
#     │   │   ├── vertices: [0, 2, 5, 6, 50, 72]
#     │   │   ├── vertices: [0, 2, 3, 6, 50, 72]
#     │   │   ├── vertices: [0, 2, 3, 5, 50, 72]
#     │   │   └── vertices: [0, 2, 3, 5, 6, 72]
#     │   ├── [73] vertices: [0, 2, 3, 4, 6, 50]
#     │   │   ├── vertices: [2, 3, 4, 6, 50, 79]
#     │   │   ├── vertices: [0, 3, 4, 6, 50, 79]
#     │   │   ├── vertices: [0, 2, 4, 6, 50, 79]
#     │   │   ├── vertices: [0, 2, 3, 6, 50, 79]
#     │   │   ├── vertices: [0, 2, 3, 4, 50, 79]
#     │   │   └── vertices: [0, 2, 3, 4, 6, 79]
#     │   └── [80] vertices: [0, 2, 3, 4, 5, 50]
#     │       ├── vertices: [2, 3, 4, 5, 50, 86]
#     │       ├── vertices: [0, 3, 4, 5, 50, 86]
#     │       ├── vertices: [0, 2, 4, 5, 50, 86]
#     │       ├── vertices: [0, 2, 3, 5, 50, 86]
#     │       ├── vertices: [0, 2, 3, 4, 50, 86]
#     │       └── vertices: [0, 2, 3, 4, 5, 86]
#     ├── [87] vertices: [0, 1, 3, 4, 5, 6]
#     │   ├── [88] vertices: [1, 3, 4, 5, 6, 93]
#     │   │   ├── vertices: [3, 4, 5, 6, 93, 94]
#     │   │   ├── vertices: [1, 4, 5, 6, 93, 94]
#     │   │   ├── vertices: [1, 3, 5, 6, 93, 94]
#     │   │   ├── vertices: [1, 3, 4, 6, 93, 94]
#     │   │   ├── vertices: [1, 3, 4, 5, 93, 94]
#     │   │   └── vertices: [1, 3, 4, 5, 6, 94]
#     │   ├── [95] vertices: [0, 3, 4, 5, 6, 93]
#     │   │   ├── vertices: [3, 4, 5, 6, 93, 101]
#     │   │   ├── vertices: [0, 4, 5, 6, 93, 101]
#     │   │   ├── vertices: [0, 3, 5, 6, 93, 101]
#     │   │   ├── vertices: [0, 3, 4, 6, 93, 101]
#     │   │   ├── vertices: [0, 3, 4, 5, 93, 101]
#     │   │   └── vertices: [0, 3, 4, 5, 6, 101]
#     │   ├── [102] vertices: [0, 1, 4, 5, 6, 93]
#     │   │   ├── vertices: [1, 4, 5, 6, 93, 108]
#     │   │   ├── vertices: [0, 4, 5, 6, 93, 108]
#     │   │   ├── vertices: [0, 1, 5, 6, 93, 108]
#     │   │   ├── vertices: [0, 1, 4, 6, 93, 108]
#     │   │   ├── vertices: [0, 1, 4, 5, 93, 108]
#     │   │   └── vertices: [0, 1, 4, 5, 6, 108]
#     │   ├── [109] vertices: [0, 1, 3, 5, 6, 93]
#     │   │   ├── vertices: [1, 3, 5, 6, 93, 115]
#     │   │   ├── vertices: [0, 3, 5, 6, 93, 115]
#     │   │   ├── vertices: [0, 1, 5, 6, 93, 115]
#     │   │   ├── vertices: [0, 1, 3, 6, 93, 115]
#     │   │   ├── vertices: [0, 1, 3, 5, 93, 115]
#     │   │   └── vertices: [0, 1, 3, 5, 6, 115]
#     │   ├── [116] vertices: [0, 1, 3, 4, 6, 93]
#     │   │   ├── vertices: [1, 3, 4, 6, 93, 122]
#     │   │   ├── vertices: [0, 3, 4, 6, 93, 122]
#     │   │   ├── vertices: [0, 1, 4, 6, 93, 122]
#     │   │   ├── vertices: [0, 1, 3, 6, 93, 122]
#     │   │   ├── vertices: [0, 1, 3, 4, 93, 122]
#     │   │   └── vertices: [0, 1, 3, 4, 6, 122]
#     │   └── [123] vertices: [0, 1, 3, 4, 5, 93]
#     │       ├── vertices: [1, 3, 4, 5, 93, 129]
#     │       ├── vertices: [0, 3, 4, 5, 93, 129]
#     │       ├── vertices: [0, 1, 4, 5, 93, 129]
#     │       ├── vertices: [0, 1, 3, 5, 93, 129]
#     │       ├── vertices: [0, 1, 3, 4, 93, 129]
#     │       └── vertices: [0, 1, 3, 4, 5, 129]
#     ├── [130] vertices: [0, 1, 2, 4, 5, 6]
#     │   ├── [131] vertices: [1, 2, 4, 5, 6, 136]
#     │   │   ├── vertices: [2, 4, 5, 6, 136, 137]
#     │   │   ├── vertices: [1, 4, 5, 6, 136, 137]
#     │   │   ├── vertices: [1, 2, 5, 6, 136, 137]
#     │   │   ├── vertices: [1, 2, 4, 6, 136, 137]
#     │   │   ├── vertices: [1, 2, 4, 5, 136, 137]
#     │   │   └── vertices: [1, 2, 4, 5, 6, 137]
#     │   ├── [138] vertices: [0, 2, 4, 5, 6, 136]
#     │   │   ├── vertices: [2, 4, 5, 6, 136, 144]
#     │   │   ├── vertices: [0, 4, 5, 6, 136, 144]
#     │   │   ├── vertices: [0, 2, 5, 6, 136, 144]
#     │   │   ├── vertices: [0, 2, 4, 6, 136, 144]
#     │   │   ├── vertices: [0, 2, 4, 5, 136, 144]
#     │   │   └── vertices: [0, 2, 4, 5, 6, 144]
#     │   ├── [145] vertices: [0, 1, 4, 5, 6, 136]
#     │   │   ├── vertices: [1, 4, 5, 6, 136, 151]
#     │   │   ├── vertices: [0, 4, 5, 6, 136, 151]
#     │   │   ├── vertices: [0, 1, 5, 6, 136, 151]
#     │   │   ├── vertices: [0, 1, 4, 6, 136, 151]
#     │   │   ├── vertices: [0, 1, 4, 5, 136, 151]
#     │   │   └── vertices: [0, 1, 4, 5, 6, 151]
#     │   ├── [152] vertices: [0, 1, 2, 5, 6, 136]
#     │   │   ├── vertices: [1, 2, 5, 6, 136, 158]
#     │   │   ├── vertices: [0, 2, 5, 6, 136, 158]
#     │   │   ├── vertices: [0, 1, 5, 6, 136, 158]
#     │   │   ├── vertices: [0, 1, 2, 6, 136, 158]
#     │   │   ├── vertices: [0, 1, 2, 5, 136, 158]
#     │   │   └── vertices: [0, 1, 2, 5, 6, 158]
#     │   ├── [159] vertices: [0, 1, 2, 4, 6, 136]
#     │   │   ├── vertices: [1, 2, 4, 6, 136, 165]
#     │   │   ├── vertices: [0, 2, 4, 6, 136, 165]
#     │   │   ├── vertices: [0, 1, 4, 6, 136, 165]
#     │   │   ├── vertices: [0, 1, 2, 6, 136, 165]
#     │   │   ├── vertices: [0, 1, 2, 4, 136, 165]
#     │   │   └── vertices: [0, 1, 2, 4, 6, 165]
#     │   └── [166] vertices: [0, 1, 2, 4, 5, 136]
#     │       ├── vertices: [1, 2, 4, 5, 136, 172]
#     │       ├── vertices: [0, 2, 4, 5, 136, 172]
#     │       ├── vertices: [0, 1, 4, 5, 136, 172]
#     │       ├── vertices: [0, 1, 2, 5, 136, 172]
#     │       ├── vertices: [0, 1, 2, 4, 136, 172]
#     │       └── vertices: [0, 1, 2, 4, 5, 172]
#     ├── [173] vertices: [0, 1, 2, 3, 5, 6]
#     │   ├── [174] vertices: [1, 2, 3, 5, 6, 179]
#     │   │   ├── vertices: [2, 3, 5, 6, 179, 180]
#     │   │   ├── vertices: [1, 3, 5, 6, 179, 180]
#     │   │   ├── vertices: [1, 2, 5, 6, 179, 180]
#     │   │   ├── vertices: [1, 2, 3, 6, 179, 180]
#     │   │   ├── vertices: [1, 2, 3, 5, 179, 180]
#     │   │   └── vertices: [1, 2, 3, 5, 6, 180]
#     │   ├── [181] vertices: [0, 2, 3, 5, 6, 179]
#     │   │   ├── vertices: [2, 3, 5, 6, 179, 187]
#     │   │   ├── vertices: [0, 3, 5, 6, 179, 187]
#     │   │   ├── vertices: [0, 2, 5, 6, 179, 187]
#     │   │   ├── vertices: [0, 2, 3, 6, 179, 187]
#     │   │   ├── vertices: [0, 2, 3, 5, 179, 187]
#     │   │   └── vertices: [0, 2, 3, 5, 6, 187]
#     │   ├── [188] vertices: [0, 1, 3, 5, 6, 179]
#     │   │   ├── vertices: [1, 3, 5, 6, 179, 194]
#     │   │   ├── vertices: [0, 3, 5, 6, 179, 194]
#     │   │   ├── vertices: [0, 1, 5, 6, 179, 194]
#     │   │   ├── vertices: [0, 1, 3, 6, 179, 194]
#     │   │   ├── vertices: [0, 1, 3, 5, 179, 194]
#     │   │   └── vertices: [0, 1, 3, 5, 6, 194]
#     │   ├── [195] vertices: [0, 1, 2, 5, 6, 179]
#     │   │   ├── vertices: [1, 2, 5, 6, 179, 201]
#     │   │   ├── vertices: [0, 2, 5, 6, 179, 201]
#     │   │   ├── vertices: [0, 1, 5, 6, 179, 201]
#     │   │   ├── vertices: [0, 1, 2, 6, 179, 201]
#     │   │   ├── vertices: [0, 1, 2, 5, 179, 201]
#     │   │   └── vertices: [0, 1, 2, 5, 6, 201]
#     │   ├── [202] vertices: [0, 1, 2, 3, 6, 179]
#     │   │   ├── vertices: [1, 2, 3, 6, 179, 208]
#     │   │   ├── vertices: [0, 2, 3, 6, 179, 208]
#     │   │   ├── vertices: [0, 1, 3, 6, 179, 208]
#     │   │   ├── vertices: [0, 1, 2, 6, 179, 208]
#     │   │   ├── vertices: [0, 1, 2, 3, 179, 208]
#     │   │   └── vertices: [0, 1, 2, 3, 6, 208]
#     │   └── [209] vertices: [0, 1, 2, 3, 5, 179]
#     │       ├── vertices: [1, 2, 3, 5, 179, 215]
#     │       ├── vertices: [0, 2, 3, 5, 179, 215]
#     │       ├── vertices: [0, 1, 3, 5, 179, 215]
#     │       ├── vertices: [0, 1, 2, 5, 179, 215]
#     │       ├── vertices: [0, 1, 2, 3, 179, 215]
#     │       └── vertices: [0, 1, 2, 3, 5, 215]
#     └── [216] vertices: [0, 1, 2, 3, 4, 6]
#         ├── [217] vertices: [1, 2, 3, 4, 6, 222]
#         │   ├── vertices: [2, 3, 4, 6, 222, 223]
#         │   ├── vertices: [1, 3, 4, 6, 222, 223]
#         │   ├── vertices: [1, 2, 4, 6, 222, 223]
#         │   ├── vertices: [1, 2, 3, 6, 222, 223]
#         │   ├── vertices: [1, 2, 3, 4, 222, 223]
#         │   └── vertices: [1, 2, 3, 4, 6, 223]
#         ├── [224] vertices: [0, 2, 3, 4, 6, 222]
#         │   ├── vertices: [2, 3, 4, 6, 222, 230]
#         │   ├── vertices: [0, 3, 4, 6, 222, 230]
#         │   ├── vertices: [0, 2, 4, 6, 222, 230]
#         │   ├── vertices: [0, 2, 3, 6, 222, 230]
#         │   ├── vertices: [0, 2, 3, 4, 222, 230]
#         │   └── vertices: [0, 2, 3, 4, 6, 230]
#         ├── [231] vertices: [0, 1, 3, 4, 6, 222]
#         │   ├── vertices: [1, 3, 4, 6, 222, 237]
#         │   ├── vertices: [0, 3, 4, 6, 222, 237]
#         │   ├── vertices: [0, 1, 4, 6, 222, 237]
#         │   ├── vertices: [0, 1, 3, 6, 222, 237]
#         │   ├── vertices: [0, 1, 3, 4, 222, 237]
#         │   └── vertices: [0, 1, 3, 4, 6, 237]
#         ├── [238] vertices: [0, 1, 2, 4, 6, 222]
#         │   ├── vertices: [1, 2, 4, 6, 222, 244]
#         │   ├── vertices: [0, 2, 4, 6, 222, 244]
#         │   ├── vertices: [0, 1, 4, 6, 222, 244]
#         │   ├── vertices: [0, 1, 2, 6, 222, 244]
#         │   ├── vertices: [0, 1, 2, 4, 222, 244]
#         │   └── vertices: [0, 1, 2, 4, 6, 244]
#         ├── [245] vertices: [0, 1, 2, 3, 6, 222]
#         │   ├── vertices: [1, 2, 3, 6, 222, 251]
#         │   ├── vertices: [0, 2, 3, 6, 222, 251]
#         │   ├── vertices: [0, 1, 3, 6, 222, 251]
#         │   ├── vertices: [0, 1, 2, 6, 222, 251]
#         │   ├── vertices: [0, 1, 2, 3, 222, 251]
#         │   └── vertices: [0, 1, 2, 3, 6, 251]
#         └── [252] vertices: [0, 1, 2, 3, 4, 222]
#             ├── vertices: [1, 2, 3, 4, 222, 258]
#             ├── vertices: [0, 2, 3, 4, 222, 258]
#             ├── vertices: [0, 1, 3, 4, 222, 258]
#             ├── vertices: [0, 1, 2, 4, 222, 258]
#             ├── vertices: [0, 1, 2, 3, 222, 258]
#             └── vertices: [0, 1, 2, 3, 4, 258]

# %%
compute_accuracy(model_5d, 5)

# %% [markdown]
# ## Test with Real Dataset: Phoneme (5D)

# %%
def test_phoneme(subdivision_levels=3, C=1000, EPSILON=0.30):
    print(f"\n{'='*60}")
    print(f"Testing Phoneme Dataset (5D)")
    print(f"{'='*60}")
    
    data = np.load('datasets/dataset_phoneme.npz')
    X, y = data['X'], data['y']
    print(f"Dataset: {X.shape[0]} points, Dimensions: {X.shape[1]}")
    print(f"Class distribution: {dict(zip(*np.unique(y, return_counts=True)))}")
    
    dimensions = X.shape[1]
    root_vertices = create_simplex_vertices(dimensions)
    print(f"Root simplex has {len(root_vertices)} vertices")
    
    model = SimplexTreeClassifier(
        vertices=root_vertices,
        classifier=LinearSVC(C=C),
        subdivision_levels=subdivision_levels,
    )
    model.fit(X, y)
    print(f"Model built with {len(model.leaf_simplexes)} leaf simplices")
    
    y_pred = model.predict(X)
    acc = accuracy_score(y, y_pred) * 100
    print(f"Accuracy: {acc:.2f}%")
    
    weights = model.classifier.coef_[0]
    intercept = model.classifier.intercept_[0]
    min_shared = dimensions
    
    nonconvex_simplex_keys = set()
    crossing_simplices = model.identify_svm_crossing_simplices()
    for i, info1 in enumerate(crossing_simplices):
        simplex1 = info1['simplex']
        for info2 in crossing_simplices[i+1:]:
            simplex2 = info2['simplex']
            shared = get_shared_vertices(simplex1, simplex2)
            if len(shared) >= min_shared:
                is_convex, avg, meeting, pt1, pt2 = check_convexity(
                    simplex1, simplex2, weights, intercept,
                    global_tree=model.tree, epsilon=EPSILON
                )
                if not is_convex:
                    nonconvex_simplex_keys.add(frozenset(simplex1.vertex_indices))
                    nonconvex_simplex_keys.add(frozenset(simplex2.vertex_indices))
    
    same_side_simplex_keys = model.find_same_side_simplices()
    combined_keys = nonconvex_simplex_keys.union(same_side_simplex_keys)
    
    print(f"\nSimplices to remove:")
    print(f"  Non-convex: {len(nonconvex_simplex_keys)}")
    print(f"  Same-side: {len(same_side_simplex_keys)}")
    print(f"  Combined: {len(combined_keys)}")
    print(f"  Leaves before: {len(model.tree.get_leaves())}")
    
    removed_count = 0
    for simplex_key in combined_keys:
        if model.tree.remove_by_leaf_key(simplex_key):
            removed_count += 1
    
    if removed_count > 0:
        model._build_node_lookup()
        model.fit(X, y)
        y_pred_after = model.predict(X)
        acc_after = accuracy_score(y, y_pred_after) * 100
    else:
        acc_after = acc
    
    print(f"\nAfter removal:")
    print(f"  Removed: {removed_count}")
    print(f"  Leaves remaining: {len(model.tree.get_leaves())}")
    print(f"  Accuracy after: {acc_after:.2f}%")
    
    return model

model_phoneme = test_phoneme(subdivision_levels=5)
# Out:
# ============================================================
# Testing Phoneme Dataset (5D)
# ============================================================
# Dataset: 5404 points, Dimensions: 5
# Class distribution: {-1.0: 3818, 1.0: 1586}
# Root simplex has 6 vertices
# (5404, 1561)
# Model built with 7776 leaf simplices
# Accuracy: 73.63%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 77
#      73     print(f"  Accuracy after: {acc_after:.2f}%")
#      75     return model
# ---> 77 model_phoneme = test_phoneme(subdivision_levels=5)
#
# Cell In[23], line 38, in test_phoneme(subdivision_levels, C, EPSILON)
#      36 for info2 in crossing_simplices[i+1:]:
#      37     simplex2 = info2['simplex']
# ---> 38     shared = get_shared_vertices(simplex1, simplex2)
#      39     if len(shared) >= min_shared:
#      40         is_convex, avg, meeting, pt1, pt2 = check_convexity(
#      41             simplex1, simplex2, weights, intercept,
#      42             global_tree=model.tree, epsilon=EPSILON
#      43         )
#
# File c:\Users\adler\SimplexTreeClassifier\in2D\tests\..\..\in2D\classifying\classes\utilss\convexity_check.py:13, in get_shared_vertices(simplex1_node, simplex2_node)
#      12 def get_shared_vertices(simplex1_node, simplex2_node):
# ---> 13     set1 = set(tuple(v) for v in simplex1_node.vertices)
#      14     set2 = set(tuple(v) for v in simplex2_node.vertices)
#      15     shared_tuples = set1.intersection(set2)
#
# File c:\Users\adler\SimplexTreeClassifier\in2D\tests\..\..\in2D\classifying\classes\utilss\convexity_check.py:13, in <genexpr>(.0)
#      12 def get_shared_vertices(simplex1_node, simplex2_node):
# ---> 13     set1 = set(tuple(v) for v in simplex1_node.vertices)
#      14     set2 = set(tuple(v) for v in simplex2_node.vertices)
#      15     shared_tuples = set1.intersection(set2)
#
# KeyboardInterrupt:
